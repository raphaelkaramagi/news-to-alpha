# %%
import yfinance as yf
import pandas as pd

# %%
apple = yf.download("AAPL", period = "3wk")
nvidia = yf.download("NVDA", period = "3wk")
walmart = yf.download("WMT", period = "3wk")
eliLilly = yf.download("LLY", period = "3wk")
jpm = yf.download("JPM", period = "3wk")
exxon = yf.download("XOM", period = "3wk")
mcd = yf.download("MCD", period = "3wk")
tesla = yf.download("TSLA", period = "3wk")
delta = yf.download("DAL", period = "3wk")
marriott = yf.download("MAR", period = "3wk")
goldman = yf.download("GS", period = "3wk")
netflix = yf.download("NFLX", period = "3wk")
meta = yf.download("META", period = "3wk") 
oracle = yf.download("ORCL", period = "3wk")
palantir = yf.download("PLTR", period = "3wk")

tickers = ["AAPL", "MSFT", "GOOGL", "WMT", "LLY", "JPM", "XOM", "MCD", "TSLA", "DAL", "MAR", "GS", "NFLX", "META", "ORCL", "PLTR"]
data = yf.download(tickers, period="3wk")

data_reorganized = data.swaplevel(axis=1).sort_index(axis=1)
data_reorganized.columns.names = ['Ticker', 'Metric'] 
data_reorganized.to_csv('multiple_stocks.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  16 of 16 completed

# %%
# !pip install yfinance finnhub-python
# Out:
# Requirement already satisfied: yfinance in /Users/timjun/miniconda3/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: finnhub-python in /Users/timjun/miniconda3/lib/python3.13/site-packages (2.4.27)
# Requirement already satisfied: pandas>=1.3.0 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (3.0.0)
# Requirement already satisfied: numpy>=1.16.5 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: pycparser in /Users/timjun/miniconda3/lib/python3.13/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/timjun/miniconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.5.0)

# %%
from finnhub import Client
from datetime import datetime, timedelta
import pytz

FINNHUB_API_KEY = "d63q9r9r01ql6dj13d4gd63q9r9r01ql6dj13d50"
finnhub_client = Client(api_key=FINNHUB_API_KEY)

PROJECT_COMPANIES = {
    "AAPL": "Apple",
    "NVDA": "NVIDIA",
    "WMT": "Walmart",
    "LLY": "Eli Lilly",
    "JPM": "JPMorgan Chase",
    "XOM": "Exxon Mobil",
    "MCD": "McDonald's",
    "TSLA": "Tesla",
    "DAL": "Delta Air Lines",
    "MAR": "Marriott International",
    "GS": "Goldman Sachs Group",
    "NFLX": "Netflix",
    "META": "Meta",
    "ORCL": "Oracle",
    "PLTR": "Palantir"
}

# %%
import yfinance as yf
import pandas as pd

# %%
apple = yf.download("AAPL", period = "3wk")
nvidia = yf.download("NVDA", period = "3wk")
walmart = yf.download("WMT", period = "3wk")
eliLilly = yf.download("LLY", period = "3wk")
jpm = yf.download("JPM", period = "3wk")
exxon = yf.download("XOM", period = "3wk")
mcd = yf.download("MCD", period = "3wk")
tesla = yf.download("TSLA", period = "3wk")
delta = yf.download("DAL", period = "3wk")
marriott = yf.download("MAR", period = "3wk")
goldman = yf.download("GS", period = "3wk")
netflix = yf.download("NFLX", period = "3wk")
meta = yf.download("META", period = "3wk") 
oracle = yf.download("ORCL", period = "3wk")
palantir = yf.download("PLTR", period = "3wk")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install yfinance finnhub-python
# Out:
# 647.12s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: yfinance in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (1.1.0)
# Collecting finnhub-python
#   Using cached finnhub_python-2.4.27-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (3.0.0)
# Requirement already satisfied: numpy>=1.16.5 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/news-to-alpha/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Using cached finnhub_python-2.4.27-py3-none-any.whl (12 kB)
# Installing collected packages: finnhub-python
# Successfully installed finnhub-python-2.4.27

# %%
from finnhub import Client
from datetime import datetime, timedelta
import pytz

FINNHUB_API_KEY = "d63q9r9r01ql6dj13d4gd63q9r9r01ql6dj13d50"
finnhub_client = Client(api_key=FINNHUB_API_KEY)

PROJECT_COMPANIES = {
    "AAPL": "Apple",
    "NVDA": "NVIDIA",
    "WMT": "Walmart",
    "LLY": "Eli Lilly",
    "JPM": "JPMorgan Chase",
    "XOM": "Exxon Mobil",
    "MCD": "McDonald's",
    "TSLA": "Tesla",
    "DAL": "Delta Air Lines",
    "MAR": "Marriott International",
    "GS": "Goldman Sachs Group",
    "NFLX": "Netflix",
    "META": "Meta",
    "ORCL": "Oracle",
    "PLTR": "Palantir"
}
